# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../simulation_data/simulation_data.csv')

print('PM2.5 Minimum: ', df['PM2.5'].min())
print('PM2.5 Maximum: ', df['PM2.5'].max())
print('PM2.5 Mean: ', df['PM2.5'].mean())
print('PM2.5 Median: ', df['PM2.5'].median())
df['PM2.5'].hist()
# Out:
# PM2.5 Minimum:  0.0
# PM2.5 Maximum:  33.65078665691597
# PM2.5 Mean:  8.721441661573307
# PM2.5 Median:  6.555350762155888
# <AxesSubplot:>

# %%
print('PM10 Minimum: ', df['PM10'].min())
print('PM10 Maximum: ', df['PM10'].max())
print('PM10 Mean: ', df['PM10'].mean())
print('PM10 Median: ', df['PM10'].median())
df['PM10'].hist()
# Out:
# PM10 Minimum:  3.1933342187869016
# PM10 Maximum:  35.219582682315824
# PM10 Mean:  13.269976726515013
# PM10 Median:  12.377538214071025
# <AxesSubplot:>
